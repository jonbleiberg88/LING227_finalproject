# %%
import numpy as np
import nltk
import keras
import gensim
# Out:
# /Users/jonathanbleiberg/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import gensim.downloader as gdl

# download pretrained 100D glove vectors
pretrained_glove = gdl.load('glove-wiki-gigaword-100')

# %%
from nltk.corpus import wordnet as wn

# get average vector of all synsets of a given word
def get_synset_vec(input_word, model, model_dim = 100, threshold = 3):
    synsets = wn.synsets(input_word)
    syn_words = set([s  for syn in synsets for s in syn.lemma_names()])
    count = 0
    syn_vec = np.zeros(model_dim)
    for word in syn_words:
        if word.lower() in model:
            syn_vec += model.get_vector(word.lower())
            count += 1
    if count < threshold:
        return False
    return (syn_vec / count)

# extract all trigrams that have a vector representation and are in wordnet
def get_trigrams(words, model, doc_id):
    wn_lemmas = set(wn.all_lemma_names())
    trigrams = [None for _ in range(len(words) - 2)]
    for i in range(len(words) - 2):
        # loop through all trigrams in text
        curr_trigram = (words[i], words[i+1], words[i+2], doc_id)
        # include trigram if all words have a vector representation
        if curr_trigram[0] in model and curr_trigram[1] in model and curr_trigram[2] in model:
            if curr_trigram[1] in wn_lemmas:
                trigrams[i] = curr_trigram
    return [tri for tri in trigrams if tri is not None]

# perturb the second word of each trigram
def get_perturbations_by_synonym(trigrams, model, use_cos_sim = True):
    perturbed_trigrams = [None for _ in range(len(trigrams))]
    wn_lemmas = set(wn.all_lemma_names())
    rand_idxs = np.random.randint(0,2,len(trigrams))
    n_syns = 0
    synset_vecs = {}
    for idx, tri in enumerate(trigrams):
        if idx % 1000 == 0:
            print(idx)
            print(n_syns)
        # get 1st-3rd most similar word to middle word of trigram
        if tri[1] in wn_lemmas:
            if tri[1] in synset_vecs.keys():
                perturbed_trigrams[idx] = synset_vecs[tri[1]]
                n_syns += 1
            else:
                v = get_synset_vec(tri[1], model, model.vector_size)
                if v is not False:
                    perturbed_trigrams[idx] = v
                    synset_vecs[tri[1]] = v
                    n_syns += 1
        elif use_cos_sim:
            perturbed_trigrams[idx] = model.most_similar(tri[1], topn=3)[rand_idxs[idx]][0]
    valid_tris = [t for t, p in zip(trigrams, perturbed_trigrams) if p is not None]
    valid_perturbed = [p for p in perturbed_trigrams if p is not None]
    return valid_tris, valid_perturbed

# create trigram and perturbed word dataset
def create_dataset(words, model, doc_id, use_cos_sim=True):
    trigrams = get_trigrams(words, model, doc_id)
    trigrams, perturbed_trigrams = get_perturbations_by_synonym(trigrams, model, use_cos_sim)
    return trigrams, perturbed_trigrams

# %%
# build the vocabulary and create dictionaries to convert between word and index
def build_vocab(trigrams):
    # extract all words in input and output
    words = [i for i, _, _, _ in trigrams] + [j for _, j, _, _ in trigrams] + [k for _, _, k, _ in trigrams]
    # get unique words
    vocab = set(words)
    
    # create dicts to convert index
    word2idx = {word:idx for idx, word in enumerate(vocab)}
    idx2word = {idx:word for idx, word in enumerate(vocab)}
    return vocab, word2idx, idx2word

# convert trigrams to concatenated vector representation
def trigrams_to_matrix(trigrams, perturbed_vecs, model, vec_size):
    word_input_matrix = np.zeros((len(trigrams), vec_size * 3))
    for idx, tri in enumerate(trigrams):
        word_input_matrix[idx] = np.concatenate((model.get_vector(tri[0]),
                                                 perturbed_vecs[idx], 
                                                 model.get_vector(tri[2])))
    return word_input_matrix

# convert middle word of trigrams to array of integer labels
def trigrams_to_labels(trigrams, word2idx):
    return np.array([word2idx[w] for _, w, _, _ in trigrams])

# extract document ids as np array
def doc_ids_to_vec(trigrams):
    return np.array([idx for _, _, _, idx in trigrams])

from sklearn.preprocessing import LabelBinarizer
# convert integer labels to one hot encoding
def convert_to_one_hot(labels, vocab_size):
    one_hot_encoder = LabelBinarizer()
    one_hot_encoder.fit(range(vocab_size))
    labels_one_hot = one_hot_encoder.transform(labels)
    return labels_one_hot

# %%
def build_inputs(trigrams, perturbed_trigrams, model):
    vocab, word2idx, idx2word = build_vocab(trigrams)
    word_input_matrix = trigrams_to_matrix(trigrams, perturbed_trigrams, model, model.vector_size)
    labels = trigrams_to_labels(trigrams, word2idx)
    labels = convert_to_one_hot(labels, len(vocab))
    doc_ids = doc_ids_to_vec(trigrams)
    
    return word_input_matrix, labels, doc_ids, vocab, word2idx, idx2word

# %%
from nltk.corpus import gutenberg

# create a dataset for the first 15000 words of each file of the Gutenberg corpus
full_tris, full_perturbed = [],[]
for idx, f in enumerate(gutenberg.fileids()):
    print(f)
    # %time trigrams, perturbed = create_dataset(gutenberg.words(fileids=f)[:15000], pretrained_glove, idx, False)
    full_tris += trigrams
    full_perturbed += perturbed
# Out:
# austen-emma.txt
# 0
# 0
# 1000
# 810
# 2000
# 1625
# 3000
# 2424
# 4000
# 3235
# 5000
# 4059
# 6000
# 4873
# CPU times: user 454 ms, sys: 52.4 ms, total: 507 ms
# Wall time: 469 ms
# austen-persuasion.txt
# 0
# 0
# 1000
# 820
# 2000
# 1619
# 3000
# 2441
# 4000
# 3253
# 5000
# 4079
# 6000
# 4880
# CPU times: user 455 ms, sys: 59.5 ms, total: 515 ms
# Wall time: 467 ms
# austen-sense.txt
# 0
# 0
# 1000
# 810
# 2000
# 1592
# 3000
# 2398
# 4000
# 3190
# 5000
# 4009
# 6000
# 4788
# CPU times: user 454 ms, sys: 39.5 ms, total: 494 ms
# Wall time: 498 ms
# bible-kjv.txt
# 0
# 0
# 1000
# 842
# 2000
# 1700
# 3000
# 2563
# 4000
# 3418
# CPU times: user 385 ms, sys: 25.2 ms, total: 410 ms
# Wall time: 433 ms
# blake-poems.txt
# 0
# 0
# 1000
# 844
# 2000
# 1682
# CPU times: user 257 ms, sys: 13.9 ms, total: 271 ms
# Wall time: 266 ms
# bryant-stories.txt
# 0
# 0
# 1000
# 872
# 2000
# 1705
# 3000
# 2566
# 4000
# 3409
# 5000
# 4207
# CPU times: user 427 ms, sys: 38.1 ms, total: 465 ms
# ...

# %%
word_input_matrix, labels, doc_ids, vocab, word2idx, idx2word = build_inputs(full_tris, full_perturbed, pretrained_glove)

# %%
word_input_matrix.shape
# Out:
# (72455, 300)

# %%
from keras.models import Model
from keras.layers import Embedding, Dense, Input, BatchNormalization, Dropout

embedding_dim = 50  # dimension of document embedding
n_docs = len(gutenberg.fileids())  # number of docs in corpus
vec_dim = 100  # dimension of word embedding vectors
hidden_size = 128  # dimension of hidden layer
vocab_size = len(vocab) # number of words in vocab
batch_size = 64 



# input layer for document id
doc_input = Input(shape=(1,), name="doc_input", dtype='int32')
# input layer for concatenated word vectors
words_input = Input(shape=(vec_dim*3,), name="word1_input", dtype='float32')

# document embedding layer
x_1 = keras.layers.Flatten()(Embedding(input_dim=n_docs, output_dim=embedding_dim, name='embeddings')(doc_input))
# concatenate document andword embeddings
X = Dropout(0.5)(BatchNormalization()(keras.layers.concatenate([x_1, words_input])))
# pass through hidden layer
X = Dropout(0.5)(BatchNormalization()(Dense(hidden_size, activation='relu')(X)))
# output softmax probailities
output = Dense(vocab_size, activation='softmax')(X)

model = Model(inputs = [doc_input, words_input], outputs=[output])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit([doc_ids, word_input_matrix], [labels], epochs=10, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 57964 samples, validate on 14491 samples
# Epoch 1/10
# 57964/57964 [==============================] - 118s 2ms/step - loss: 4.8780 - acc: 0.3866 - val_loss: 3.5305 - val_acc: 0.5703
# Epoch 2/10
# 57964/57964 [==============================] - 112s 2ms/step - loss: 2.4361 - acc: 0.6401 - val_loss: 2.5286 - val_acc: 0.6940
# Epoch 3/10
# 57964/57964 [==============================] - 103s 2ms/step - loss: 1.7122 - acc: 0.7197 - val_loss: 2.1636 - val_acc: 0.7426
# Epoch 4/10
# 57964/57964 [==============================] - 21s 370us/step - loss: 1.3750 - acc: 0.7552 - val_loss: 1.9946 - val_acc: 0.7693
# Epoch 5/10
# 57964/57964 [==============================] - 107s 2ms/step - loss: 1.1796 - acc: 0.7749 - val_loss: 1.9111 - val_acc: 0.7830
# Epoch 6/10
# 57964/57964 [==============================] - 107s 2ms/step - loss: 1.0415 - acc: 0.7897 - val_loss: 1.8541 - val_acc: 0.7977
# Epoch 7/10
# ...

# %%
model.fit([doc_ids, word_input_matrix], [labels], epochs=10, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 57964 samples, validate on 14491 samples
# Epoch 1/10
# 57964/57964 [==============================] - 103s 2ms/step - loss: 0.7558 - acc: 0.8246 - val_loss: 1.7308 - val_acc: 0.8344
# Epoch 2/10
# 57964/57964 [==============================] - 105s 2ms/step - loss: 0.7202 - acc: 0.8291 - val_loss: 1.7248 - val_acc: 0.8351
# Epoch 3/10
# 57964/57964 [==============================] - 104s 2ms/step - loss: 0.7053 - acc: 0.8303 - val_loss: 1.7249 - val_acc: 0.8365
# Epoch 4/10
# 57964/57964 [==============================] - 108s 2ms/step - loss: 0.6828 - acc: 0.8332 - val_loss: 1.7187 - val_acc: 0.8392
# Epoch 5/10
# 57964/57964 [==============================] - 108s 2ms/step - loss: 0.6579 - acc: 0.8392 - val_loss: 1.7228 - val_acc: 0.8392
# Epoch 6/10
# 57964/57964 [==============================] - 104s 2ms/step - loss: 0.6466 - acc: 0.8402 - val_loss: 1.7114 - val_acc: 0.8378
# Epoch 7/10
# ...

# %%
model.fit([doc_ids, word_input_matrix], [labels], epochs=5, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 57964 samples, validate on 14491 samples
# Epoch 1/5
# 57964/57964 [==============================] - 105s 2ms/step - loss: 0.5941 - acc: 0.8488 - val_loss: 1.7041 - val_acc: 0.8432
# Epoch 2/5
# 57964/57964 [==============================] - 105s 2ms/step - loss: 0.5947 - acc: 0.8476 - val_loss: 1.6848 - val_acc: 0.8480
# Epoch 3/5
# 57964/57964 [==============================] - 99s 2ms/step - loss: 0.5843 - acc: 0.8510 - val_loss: 1.6916 - val_acc: 0.8473
# Epoch 4/5
# 57964/57964 [==============================] - 105s 2ms/step - loss: 0.5717 - acc: 0.8533 - val_loss: 1.6975 - val_acc: 0.8487
# Epoch 5/5
# 57964/57964 [==============================] - 97s 2ms/step - loss: 0.5688 - acc: 0.8540 - val_loss: 1.6824 - val_acc: 0.8510

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

def visualize(model, labels, use_tsne = True, perplexity = 3):
    embed = model.layers[1].get_weights()[0]
    # standardize embeddings
    scaler = StandardScaler()
    standardized_embeddings = scaler.fit_transform(embed)

    # reduce to 2D with TSNE
    tsne_1 = TSNE(random_state=42, perplexity=perplexity)
    embeddings_2d_tsne = tsne_1.fit_transform(standardized_embeddings)

    # reduce to 2D with PCA
    pca_1 = PCA(n_components=2)
    embeddings_2d_pca = pca_1.fit_transform(standardized_embeddings)
    if not use_tsne:
        # plot the PCA reduced embeddings
        plt.scatter(embeddings_2d_pca[:,0], embeddings_2d_pca[:,1])

        for label, x, y in zip(labels, embeddings_2d_pca[:, 0], embeddings_2d_pca[:, 1]):
            plt.annotate(
                label,
                xy=(x, y), xytext=(-2, y),
                textcoords='offset points', ha='right', va='bottom')
    else: 
        plt.scatter(embeddings_2d_tsne[:,0], embeddings_2d_tsne[:,1])

        for label, x, y in zip(labels, embeddings_2d_tsne[:, 0], embeddings_2d_tsne[:, 1]):
            plt.annotate(
                label,
                xy=(x, y), xytext=(-2,0),
                textcoords='offset points', ha='right', va='bottom')
    plt.show()

# %%
visualize(model, gutenberg.fileids(), False)

# %%
visualize(model, [f.split('-')[0] for f in gutenberg.fileids()], True, 3)

# %%
model.save("gutenberg_fix_1.h5")

# %%
from nltk.corpus import gutenberg
[(f, len(gutenberg.words(fileids=f))) for f in gutenberg.fileids()]
# Out:
# [('austen-emma.txt', 192427),
#  ('austen-persuasion.txt', 98171),
#  ('austen-sense.txt', 141576),
#  ('bible-kjv.txt', 1010654),
#  ('blake-poems.txt', 8354),
#  ('bryant-stories.txt', 55563),
#  ('burgess-busterbrown.txt', 18963),
#  ('carroll-alice.txt', 34110),
#  ('chesterton-ball.txt', 96996),
#  ('chesterton-brown.txt', 86063),
#  ('chesterton-thursday.txt', 69213),
#  ('edgeworth-parents.txt', 210663),
#  ('melville-moby_dick.txt', 260819),
#  ('milton-paradise.txt', 96825),
#  ('shakespeare-caesar.txt', 25833),
#  ('shakespeare-hamlet.txt', 37360),
#  ('shakespeare-macbeth.txt', 23140),
#  ('whitman-leaves.txt', 154883)]

# %%
# now with 50000 word text corpus

full_tris, full_perturbed = [],[]
for idx, f in enumerate(gutenberg.fileids()):
    print(f)
    # %time trigrams, perturbed = create_dataset(gutenberg.words(fileids=f)[:50000], pretrained_glove, idx, False)
    full_tris += trigrams
    full_perturbed += perturbed
# Out:
# austen-emma.txt
# 0
# 0
# 1000
# 810
# 2000
# 1625
# 3000
# 2424
# 4000
# 3235
# 5000
# 4059
# 6000
# 4873
# 7000
# 5682
# 8000
# 6469
# 9000
# 7274
# 10000
# 8101
# 11000
# 8916
# 12000
# 9718
# 13000
# 10515
# 14000
# 11324
# 15000
# 12131
# 16000
# 12929
# 17000
# 13722
# 18000
# 14554
# 19000
# 15374
# 20000
# 16183
# CPU times: user 5 s, sys: 4.21 s, total: 9.21 s
# Wall time: 9.44 s
# austen-persuasion.txt
# 0
# 0
# 1000
# 820
# 2000
# 1619
# 3000
# 2441
# 4000
# 3253
# 5000
# 4079
# 6000
# 4880
# 7000
# 5678
# 8000
# 6496
# 9000
# 7308
# 10000
# 8125
# 11000
# 8937
# 12000
# 9756
# 13000
# 10574
# 14000
# 11387
# 15000
# 12192
# 16000
# 13001
# 17000
# 13820
# 18000
# 14658
# 19000
# 15497
# 20000
# 16301
# CPU times: user 1.86 s, sys: 1.64 s, total: 3.5 s
# Wall time: 3.59 s
# austen-sense.txt
# 0
# 0
# 1000
# 810
# 2000
# 1592
# 3000
# 2398
# 4000
# 3190
# 5000
# 4009
# 6000
# 4788
# 7000
# 5612
# 8000
# 6432
# 9000
# 7243
# 10000
# 8031
# 11000
# 8843
# 12000
# 9626
# ...

# %%
word_input_matrix, labels, doc_ids, vocab, word2idx, idx2word = build_inputs(full_tris, full_perturbed, pretrained_glove)

# %%
word_input_matrix.shape
# Out:
# (213999, 300)

# %%
from keras.models import Model
from keras.layers import Embedding, Dense, Input, BatchNormalization, Dropout

embedding_dim = 50  # dimension of document embedding
n_docs = len(gutenberg.fileids())  # number of docs in corpus
vec_dim = 100  # dimension of word embedding vectors
hidden_size = 128  # dimension of hidden layer
vocab_size = len(vocab) # number of words in vocab
batch_size = 64 



# input layer for document id
doc_input = Input(shape=(1,), name="doc_input", dtype='int32')
# input layer for concatenated word vectors
words_input = Input(shape=(vec_dim*3,), name="word1_input", dtype='float32')

# document embedding layer
x_1 = keras.layers.Flatten()(Embedding(input_dim=n_docs, output_dim=embedding_dim, name='embeddings')(doc_input))
# concatenate document andword embeddings
X = Dropout(0.5)(BatchNormalization()(keras.layers.concatenate([x_1, words_input])))
# pass through hidden layer
X = Dropout(0.5)(BatchNormalization()(Dense(hidden_size, activation='relu')(X)))
# output softmax probailities
output = Dense(vocab_size, activation='softmax')(X)

model = Model(inputs = [doc_input, words_input], outputs=[output])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit([doc_ids, word_input_matrix], [labels], epochs=3, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 171199 samples, validate on 42800 samples
# Epoch 1/3
# 171199/171199 [==============================] - 521s 3ms/step - loss: 0.9007 - acc: 0.8167 - val_loss: 1.3118 - val_acc: 0.8484
# Epoch 2/3
#  72320/171199 [===========>..................] - ETA: 5:04 - loss: 0.8532 - acc: 0.8214

# %%
model.save("gutenberg_fix_2.h5")

# %%
model.fit([doc_ids, word_input_matrix], [labels], epochs=3, batch_size=batch_size, validation_split=0.2)
