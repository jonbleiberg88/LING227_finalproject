# %%
import numpy as np
import nltk
import keras
import gensim
# Out:
# /Users/jonathanbleiberg/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from nltk.corpus import brown
import gensim.downloader as gdl

pretrained_glove = gdl.load('glove-wiki-gigaword-100')

# %%
import random

# extract all trigrams that have a vector representation
def get_trigrams(words, model, doc_id):
    trigrams = [None for _ in range(len(words) - 2)]
    for i in range(len(words) - 2):
        # loop through all trigrams in text
        curr_trigram = (words[i], words[i+1], words[i+2], doc_id)
        # include trigram if all words have a vector representation
        if curr_trigram[0] in model and curr_trigram[1] in model and curr_trigram[2] in model:
            trigrams[i] = curr_trigram
    return [tri for tri in trigrams if tri is not None]

# perturb the second word of each trigram
def get_perturbations_by_synonym(trigrams, model):
    perturbed_trigrams = [None for _ in range(len(trigrams))]
    wn_lemmas = set(wn.all_lemma_names())
    rand_idxs = np.random.randint(0,2,len(trigrams))
    n_syns = 0
    for idx, tri in enumerate(trigrams):
        if idx % 1000 == 0:
            print(idx)
            print(n_syns)
        # get 1st-3rd most similar word to middle word of trigram
        if tri[1] in wn_lemmas:
            syns = [w for w in random.choice(wn.synsets(tri[1])).lemma_names() if w != tri[1] and w in model]
            if syns != []:
                n_syns += 1
                perturbed_trigrams[idx] = random.choice(syns)
        else:
            perturbed_trigrams[idx] = model.most_similar(tri[1], topn=3)[rand_idxs[idx]][0]
    
    return perturbed_trigrams

# create trigram and perturbed word dataset
def create_dataset_v2(words, model, doc_id):
    trigrams = get_trigrams(words, model, doc_id)
    perturbed_trigrams = get_perturbations_by_synonym(trigrams, model)
    return trigrams, perturbed_trigrams

# %%
from nltk.corpus import wordnet as wn
from nltk.corpus import gutenberg

full_tris, full_perturbed_v2 = [],[]
for idx, f in enumerate(gutenberg.fileids()):
    print(f)
    # %time trigrams, perturbed = create_dataset_v2(gutenberg.words(fileids=f)[:10000], pretrained_glove, idx)
    full_tris += trigrams
    full_perturbed_v2 += perturbed
    
for idx, cat in enumerate(brown.categories()):
    print(cat)
    # %time trigrams, perturbed = create_dataset_v2(brown.words(categories=cat)[:10000], pretrained_glove, idx + len(gutenberg.fileids()))
    full_tris += trigrams
    full_perturbed_v2 += perturbed
# Out:
# austen-emma.txt
# 0
# 0
# 1000
# 303
# 2000
# 616
# 3000
# 918
# 4000
# 1225
# 5000
# 1533
# 6000
# 1850
# 7000
# 2140
# CPU times: user 2min 28s, sys: 2.38 s, total: 2min 30s
# Wall time: 1min 26s
# austen-persuasion.txt
# 0
# 0
# 1000
# 289
# 2000
# 582
# 3000
# 889
# 4000
# 1209
# 5000
# 1534
# 6000
# 1832
# 7000
# 2129
# CPU times: user 2min 31s, sys: 1.26 s, total: 2min 33s
# Wall time: 1min 25s
# austen-sense.txt
# 0
# 0
# 1000
# 293
# 2000
# 566
# 3000
# 868
# 4000
# 1182
# 5000
# 1479
# 6000
# 1813
# 7000
# 2088
# CPU times: user 2min 38s, sys: 955 ms, total: 2min 39s
# Wall time: 1min 29s
# bible-kjv.txt
# 0
# 0
# 1000
# 248
# 2000
# 502
# 3000
# 827
# 4000
# 1081
# 5000
# 1307
# 6000
# 1588
# 7000
# 1852
# CPU times: user 2min 47s, sys: 836 ms, total: 2min 48s
# Wall time: 1min 34s
# blake-poems.txt
# 0
# 0
# 1000
# 329
# 2000
# 708
# 3000
# 1003
# 4000
# 1337
# CPU times: user 1min 18s, sys: 781 ms, total: 1min 18s
# Wall time: 44.4 s
# bryant-stories.txt
# 0
# 0
# 1000
# 273
# 2000
# 546
# 3000
# 816
# 4000
# 1081
# 5000
# 1371
# 6000
# 1664
# CPU times: user 2min 10s, sys: 798 ms, total: 2min 11s
# Wall time: 1min 13s
# burgess-busterbrown.txt
# 0
# 0
# 1000
# 299
# 2000
# 608
# 3000
# 913
# 4000
# 1220
# 5000
# 1517
# 6000
# 1802
# CPU times: user 1min 51s, sys: 502 ms, total: 1min 51s
# Wall time: 1min 2s
# carroll-alice.txt
# 0
# 0
# 1000
# 265
# 2000
# 537
# 3000
# 847
# 4000
# 1126
# 5000
# 1419
# 6000
# 1702
# CPU times: user 2min 19s, sys: 660 ms, total: 2min 20s
# Wall time: 1min 18s
# chesterton-ball.txt
# 0
# 0
# 1000
# 297
# 2000
# 594
# 3000
# 893
# 4000
# 1205
# 5000
# 1522
# 6000
# 1865
# 7000
# 2195
# CPU times: user 2min 21s, sys: 895 ms, total: 2min 22s
# Wall time: 1min 19s
# chesterton-brown.txt
# 0
# 0
# 1000
# 311
# 2000
# 597
# 3000
# 899
# 4000
# 1204
# 5000
# 1537
# 6000
# 1856
# 7000
# 2155
# CPU times: user 2min 46s, sys: 1.04 s, total: 2min 47s
# Wall time: 31min 47s
# chesterton-thursday.txt
# 0
# 0
# 1000
# 317
# 2000
# 596
# 3000
# 887
# 4000
# 1204
# 5000
# 1507
# 6000
# 1827
# 7000
# 2126
# CPU times: user 3min 15s, sys: 1.04 s, total: 3min 16s
# Wall time: 1min 55s
# edgeworth-parents.txt
# 0
# 0
# 1000
# 254
# 2000
# 510
# 3000
# 796
# 4000
# 1085
# 5000
# 1334
# 6000
# 1603
# 7000
# 1889
# CPU times: user 4min 15s, sys: 943 ms, total: 4min 16s
# Wall time: 2min 29s
# melville-moby_dick.txt
# 0
# 0
# 1000
# 306
# 2000
# 592
# 3000
# 876
# 4000
# 1154
# 5000
# 1442
# 6000
# 1726
# CPU times: user 3min 3s, sys: 1.03 s, total: 3min 4s
# Wall time: 1min 48s
# milton-paradise.txt
# 0
# 0
# 1000
# 334
# 2000
# 634
# 3000
# 923
# 4000
# 1243
# 5000
# 1555
# CPU times: user 2min 13s, sys: 742 ms, total: 2min 14s
# Wall time: 1min 18s
# shakespeare-caesar.txt
# 0
# 0
# 1000
# 271
# 2000
# 541
# 3000
# 835
# CPU times: user 1min 22s, sys: 316 ms, total: 1min 22s
# Wall time: 48.2 s
# shakespeare-hamlet.txt
# 0
# 0
# 1000
# 263
# 2000
# 550
# 3000
# 818
# CPU times: user 1min 21s, sys: 322 ms, total: 1min 21s
# Wall time: 47.7 s
# shakespeare-macbeth.txt
# 0
# 0
# 1000
# 294
# 2000
# 565
# CPU times: user 1min 20s, sys: 326 ms, total: 1min 21s
# Wall time: 47.3 s
# whitman-leaves.txt
# 0
# 0
# 1000
# 268
# 2000
# 548
# 3000
# 833
# 4000
# 1134
# 5000
# 1394
# 6000
# 1676
# CPU times: user 2min 58s, sys: 870 ms, total: 2min 59s
# Wall time: 1min 44s
# adventure
# 0
# 0
# 1000
# 264
# 2000
# 523
# 3000
# 793
# 4000
# 1047
# 5000
# 1311
# 6000
# 1605
# CPU times: user 7min 36s, sys: 3.42 s, total: 7min 39s
# Wall time: 4min 20s
# belles_lettres
# 0
# 0
# 1000
# 288
# 2000
# 583
# 3000
# 872
# 4000
# 1160
# 5000
# 1458
# 6000
# 1760
# 7000
# 2049
# CPU times: user 4min 31s, sys: 1.74 s, total: 4min 32s
# Wall time: 2min 41s
# editorial
# 0
# 0
# 1000
# 301
# 2000
# 631
# 3000
# 986
# 4000
# 1275
# 5000
# 1601
# 6000
# 1899
# CPU times: user 4min 2s, sys: 1.68 s, total: 4min 4s
# Wall time: 2min 25s
# fiction
# 0
# 0
# 1000
# 329
# 2000
# 638
# 3000
# 945
# 4000
# 1243
# 5000
# 1569
# 6000
# 1852
# 7000
# 2156
# CPU times: user 4min 21s, sys: 1.46 s, total: 4min 22s
# Wall time: 2min 35s
# government
# 0
# 0
# 1000
# 315
# 2000
# 633
# 3000
# 969
# 4000
# 1266
# 5000
# 1565
# 6000
# 1869
# 7000
# 2176
# CPU times: user 4min 41s, sys: 1.59 s, total: 4min 42s
# Wall time: 2min 49s
# hobbies
# 0
# 0
# 1000
# 297
# 2000
# 601
# 3000
# 922
# 4000
# 1255
# 5000
# 1549
# 6000
# 1858
# 7000
# 2138
# CPU times: user 4min 34s, sys: 1.66 s, total: 4min 35s
# Wall time: 2min 44s
# humor
# 0
# 0
# 1000
# 267
# 2000
# 536
# 3000
# 804
# 4000
# 1090
# 5000
# 1389
# 6000
# 1708
# 7000
# 2020
# CPU times: user 4min 46s, sys: 1.69 s, total: 4min 47s
# Wall time: 16min 13s
# learned
# 0
# 0
# 1000
# 289
# 2000
# 618
# 3000
# 928
# 4000
# 1210
# 5000
# 1510
# 6000
# 1825
# 7000
# 2142
# CPU times: user 3min 17s, sys: 942 ms, total: 3min 18s
# Wall time: 1min 55s
# lore
# 0
# 0
# 1000
# 315
# 2000
# 597
# 3000
# 893
# 4000
# 1176
# 5000
# 1496
# 6000
# 1801
# 7000
# 2076
# CPU times: user 3min 27s, sys: 829 ms, total: 3min 28s
# Wall time: 2min 2s
# mystery
# 0
# 0
# 1000
# 306
# 2000
# 597
# 3000
# 897
# 4000
# 1159
# 5000
# 1446
# 6000
# 1758
# CPU times: user 2min 56s, sys: 738 ms, total: 2min 57s
# Wall time: 1min 43s
# news
# 0
# 0
# 1000
# 298
# 2000
# 636
# 3000
# 938
# 4000
# 1243
# 5000
# 1561
# 6000
# 1899
# CPU times: user 2min 33s, sys: 666 ms, total: 2min 33s
# Wall time: 1min 29s
# religion
# 0
# 0
# 1000
# 314
# 2000
# 623
# 3000
# 928
# 4000
# 1230
# 5000
# 1541
# 6000
# 1845
# 7000
# 2149
# CPU times: user 2min 57s, sys: 708 ms, total: 2min 58s
# Wall time: 1min 43s
# reviews
# 0
# 0
# 1000
# 317
# 2000
# 622
# 3000
# 941
# 4000
# 1228
# 5000
# 1525
# 6000
# 1863
# CPU times: user 2min 37s, sys: 721 ms, total: 2min 38s
# Wall time: 1min 31s
# romance
# 0
# 0
# 1000
# 276
# 2000
# 570
# 3000
# 852
# 4000
# 1124
# 5000
# 1385
# 6000
# 1669
# 7000
# 1957
# CPU times: user 8min, sys: 3.47 s, total: 8min 3s
# Wall time: 4min 34s
# science_fiction
# 0
# 0
# 1000
# 280
# 2000
# 557
# 3000
# 864
# 4000
# 1161
# 5000
# 1442
# 6000
# 1725
# CPU times: user 3min 48s, sys: 1.01 s, total: 3min 49s
# Wall time: 2min 15s

# %%
# build the vocabulary and create dictionaries to convert between word and index
def build_vocab(trigrams, perturbed_trigrams):
    # extract all words in input and output
    words = [i for i, _, _, _ in trigrams] + [trigrams[-1][1]] + [trigrams[-1][2]]
    words += [i for i in perturbed_trigrams]
    # get unique words
    vocab = set(words)
    
    # create dicts to conver index
    word2idx = {word:idx for idx, word in enumerate(vocab)}
    idx2word = {idx:word for idx, word in enumerate(vocab)}
    return vocab, word2idx, idx2word

# %%
vocab, word2idx, idx2word = build_vocab(full_tris, full_perturbed_v2)

# %%
# convert trigrams to concatenated vector representation
def trigrams_to_matrix(trigrams, model, vec_size):
    word_input_matrix = np.zeros((len(trigrams), vec_size * 3))
    for idx, tri in enumerate(trigrams):
        word_input_matrix[idx] = np.concatenate((model.get_vector(tri[0]),
                                                 model.get_vector(tri[1]), 
                                                 model.get_vector(tri[2])))
    return word_input_matrix
# convert perturbed words to array of integer labels
def perturbed_to_labels(perturbed, word2idx):
    return np.array([word2idx[w] for w in perturbed])

# extract document ids as np array
def doc_ids_to_vec(trigrams):
    return np.array([idx for _, _, _, idx in trigrams])

# %%
word_input_mat = trigrams_to_matrix(full_tris, pretrained_glove, 100)
labels = perturbed_to_labels(full_perturbed_v2, word2idx)
doc_ids = doc_ids_to_vec(full_tris)

# %%
from sklearn.preprocessing import LabelBinarizer
# convert interger labels to one hot encoding
def convert_to_one_hot(labels, vocab_size):
    one_hot_encoder = LabelBinarizer()
    one_hot_encoder.fit(range(vocab_size))
    labels_one_hot = one_hot_encoder.transform(labels)
    return labels_one_hot

# %%
labels_one_hot = convert_to_one_hot(labels, len(vocab))

# %%
from keras.models import Model
from keras.layers import Embedding, Dense, Input

embedding_dim = 50  # dimension of document embedding
n_docs = len(brown.categories()) + len(gutenberg.fileids())  # number of docs in corpus
vec_dim = 100  # dimension of word embedding vectors
hidden_size = 128  # dimension of hidden layer
vocab_size = len(vocab) # number of words in vocab
batch_size = 64 



# input layer for document id
doc_input = Input(shape=(1,), name="doc_input", dtype='int32')
# input layer for concatenated word vectors
words_input = Input(shape=(vec_dim*3,), name="word1_input", dtype='float32')

# document embedding layer
x_1 = keras.layers.Flatten()(Embedding(input_dim=n_docs, output_dim=embedding_dim, name='embeddings')(doc_input))
# concatenate document andword embeddings
X = keras.layers.concatenate([x_1, words_input])
# pass through hidden layer
X = Dense(hidden_size, activation='relu')(X)
# output softmax probailities
output = Dense(vocab_size, activation='softmax')(X)

model = Model(inputs = [doc_input, words_input], outputs=[output])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# train for 20 epochs
model.fit([doc_ids, word_input_mat], [labels_one_hot], epochs=20, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 174064 samples, validate on 43517 samples
# Epoch 1/20
# 174064/174064 [==============================] - 1571s 9ms/step - loss: 3.5409 - acc: 0.4251 - val_loss: 3.3685 - val_acc: 0.4521
# Epoch 2/20
# 174064/174064 [==============================] - 1627s 9ms/step - loss: 2.2521 - acc: 0.4757 - val_loss: 3.2293 - val_acc: 0.4647
# Epoch 3/20
# 174064/174064 [==============================] - 1656s 10ms/step - loss: 1.7009 - acc: 0.5055 - val_loss: 3.3113 - val_acc: 0.4641
# Epoch 4/20
# 174064/174064 [==============================] - 1656s 10ms/step - loss: 1.3997 - acc: 0.5304 - val_loss: 3.3720 - val_acc: 0.4648
# Epoch 5/20
# 174064/174064 [==============================] - 1667s 10ms/step - loss: 1.2196 - acc: 0.5579 - val_loss: 3.5484 - val_acc: 0.4609
# Epoch 6/20
# 174064/174064 [==============================] - 1664s 10ms/step - loss: 1.1045 - acc: 0.5805 - val_loss: 3.4442 - val_acc: 0.4652
# Epoch 7/20
# 174064/174064 [==============================] - 1656s 10ms/step - loss: 1.0241 - acc: 0.6029 - val_loss: 3.6085 - val_acc: 0.4625
# Epoch 8/20
# 174064/174064 [==============================] - 1179s 7ms/step - loss: 0.9649 - acc: 0.6177 - val_loss: 3.7748 - val_acc: 0.4617
# Epoch 9/20
# 174064/174064 [==============================] - 2742s 16ms/step - loss: 0.9155 - acc: 0.6328 - val_loss: 3.6643 - val_acc: 0.4634
# Epoch 10/20
# 174064/174064 [==============================] - 1548s 9ms/step - loss: 0.8773 - acc: 0.6435 - val_loss: 3.8995 - val_acc: 0.4629
# Epoch 11/20
# 174064/174064 [==============================] - 1634s 9ms/step - loss: 0.8422 - acc: 0.6568 - val_loss: 3.8391 - val_acc: 0.4633
# Epoch 12/20
# 174064/174064 [==============================] - 1660s 10ms/step - loss: 0.8122 - acc: 0.6671 - val_loss: 3.9631 - val_acc: 0.4611
# Epoch 13/20
# 174064/174064 [==============================] - 1679s 10ms/step - loss: 0.7859 - acc: 0.6741 - val_loss: 3.9314 - val_acc: 0.4636
# Epoch 14/20
# 174064/174064 [==============================] - 2085s 12ms/step - loss: 0.7621 - acc: 0.6833 - val_loss: 3.9671 - val_acc: 0.4626
# Epoch 15/20
# 174064/174064 [==============================] - 1694s 10ms/step - loss: 0.7418 - acc: 0.6905 - val_loss: 3.9778 - val_acc: 0.4660
# Epoch 16/20
# 174064/174064 [==============================] - 1618s 9ms/step - loss: 0.7231 - acc: 0.6984 - val_loss: 4.0068 - val_acc: 0.4642
# Epoch 17/20
# 174064/174064 [==============================] - 854s 5ms/step - loss: 0.7058 - acc: 0.7038 - val_loss: 4.0469 - val_acc: 0.4659
# Epoch 18/20
# 174064/174064 [==============================] - 2916s 17ms/step - loss: 0.6908 - acc: 0.7094 - val_loss: 4.0328 - val_acc: 0.4661
# Epoch 19/20
# 174064/174064 [==============================] - 760s 4ms/step - loss: 0.6758 - acc: 0.7153 - val_loss: 4.1509 - val_acc: 0.4663
# Epoch 20/20
# 174064/174064 [==============================] - 2759s 16ms/step - loss: 0.6635 - acc: 0.7202 - val_loss: 4.1609 - val_acc: 0.4651

# %%
model.save('combined_first_10000_v2.h5')

# %%
embed = model.layers[1].get_weights()[0]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA


scaler = StandardScaler()
standardized_embeddings = scaler.fit_transform(embed)

tsne_1 = TSNE(random_state=42, perplexity=2)
embeddings_2d_tsne = tsne_1.fit_transform(standardized_embeddings)

pca_1 = PCA(n_components=2)
embeddings_2d_pca = pca_1.fit_transform(standardized_embeddings)

# %%
import matplotlib.pyplot as plt

plt.scatter(embeddings_2d_pca[:,0], embeddings_2d_pca[:,1])

for label, x, y in zip(brown.categories() + gutenberg.fileids(), embeddings_2d_pca[:, 0], embeddings_2d_pca[:, 1]):
    plt.annotate(
        label,
        xy=(x, y), xytext=(-2, y),
        textcoords='offset points', ha='right', va='bottom')
plt.show()

# %%
plt.scatter(embeddings_2d_tsne[:,0], embeddings_2d_tsne[:,1])

for label, x, y in zip(brown.categories() + gutenberg.fileids(), embeddings_2d_tsne[:, 0], embeddings_2d_tsne[:, 1]):
    plt.annotate(
        label,
        xy=(x, y), xytext=(-2,0),
        textcoords='offset points', ha='right', va='bottom')
plt.show()

# %%
from keras.models import Model
from keras.layers import Embedding, Dense, Input, BatchNormalization
from keras.regularizers import l2

embedding_dim = 50  # dimension of document embedding
n_docs = len(brown.categories()) + len(gutenberg.fileids())  # number of docs in corpus
vec_dim = 100  # dimension of word embedding vectors
hidden_size = 64  # dimension of hidden layer
vocab_size = len(vocab) # number of words in vocab
batch_size = 64 



# input layer for document id
doc_input = Input(shape=(1,), name="doc_input", dtype='int32')
# input layer for concatenated word vectors
words_input = Input(shape=(vec_dim*3,), name="word1_input", dtype='float32')

# document embedding layer
x_1 = BatchNormalization()(keras.layers.Flatten()(Embedding(input_dim=n_docs, 
                                                          output_dim=embedding_dim, name='embeddings')(doc_input)))
# concatenate document and word embeddings
X = BatchNormalization()(keras.layers.concatenate([x_1, words_input]))
# pass through hidden layer
X = Dense(hidden_size, activation='relu', kernel_regularizer=l2(0.01))(X)
# output softmax probailities
output = Dense(vocab_size, activation='softmax')(X)

model2 = Model(inputs = [doc_input, words_input], outputs=[output])

# %%
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model2.fit([doc_ids, word_input_mat], [labels_one_hot], epochs=3, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 174064 samples, validate on 43517 samples
# Epoch 1/3
# 174064/174064 [==============================] - 703s 4ms/step - loss: 3.7800 - acc: 0.4246 - val_loss: 3.2315 - val_acc: 0.4580
# Epoch 2/3
# 174064/174064 [==============================] - 698s 4ms/step - loss: 2.5476 - acc: 0.4662 - val_loss: 2.9267 - val_acc: 0.4715
# Epoch 3/3
# 174064/174064 [==============================] - 657s 4ms/step - loss: 2.1039 - acc: 0.4807 - val_loss: 2.7732 - val_acc: 0.4826

# %%
model2.fit([doc_ids, word_input_mat], [labels_one_hot], epochs=3, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 174064 samples, validate on 43517 samples
# Epoch 1/3
# 174064/174064 [==============================] - 665s 4ms/step - loss: 1.8394 - acc: 0.4918 - val_loss: 2.6909 - val_acc: 0.4846
# Epoch 2/3
# 174064/174064 [==============================] - 643s 4ms/step - loss: 1.6819 - acc: 0.4997 - val_loss: 2.6296 - val_acc: 0.4863
# Epoch 3/3
# 174064/174064 [==============================] - 652s 4ms/step - loss: 1.5749 - acc: 0.5048 - val_loss: 2.6057 - val_acc: 0.4841

# %%
from keras.models import Model
from keras.layers import Embedding, Dense, Input, BatchNormalization, Dropout
from keras.regularizers import l2

embedding_dim = 50  # dimension of document embedding
n_docs = len(brown.categories()) + len(gutenberg.fileids())  # number of docs in corpus
vec_dim = 100  # dimension of word embedding vectors
hidden_size = 64  # dimension of hidden layer
vocab_size = len(vocab) # number of words in vocab
batch_size = 64 



# input layer for document id
doc_input = Input(shape=(1,), name="doc_input", dtype='int32')
# input layer for concatenated word vectors
words_input = Input(shape=(vec_dim*3,), name="word1_input", dtype='float32')

# document embedding layer
x_1 = keras.layers.Flatten()(Embedding(input_dim=n_docs, 
                                                          output_dim=embedding_dim, name='embeddings')(doc_input))
# concatenate document and word embeddings
X = Dropout(0.5)(BatchNormalization()(keras.layers.concatenate([x_1, words_input])))
# pass through hidden layer
X = Dropout(0.5)(BatchNormalization()(Dense(hidden_size, activation='relu', kernel_regularizer=l2(0.01))(X)))
# output softmax probailities
output = Dense(vocab_size, activation='softmax')(X)

model3 = Model(inputs = [doc_input, words_input], outputs=[output])

# %%
model3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model3.fit([doc_ids, word_input_mat], [labels_one_hot], epochs=5, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 174064 samples, validate on 43517 samples
# Epoch 1/5
# 174064/174064 [==============================] - 645s 4ms/step - loss: 4.8298 - acc: 0.3548 - val_loss: 3.7290 - val_acc: 0.4320
# Epoch 2/5
# 174064/174064 [==============================] - 651s 4ms/step - loss: 3.8207 - acc: 0.3935 - val_loss: 3.4738 - val_acc: 0.4357
# Epoch 3/5
# 174064/174064 [==============================] - 644s 4ms/step - loss: 3.5841 - acc: 0.3980 - val_loss: 3.3407 - val_acc: 0.4486
# Epoch 4/5
# 174064/174064 [==============================] - 644s 4ms/step - loss: 3.4448 - acc: 0.4011 - val_loss: 3.2522 - val_acc: 0.4478
# Epoch 5/5
# 174064/174064 [==============================] - 648s 4ms/step - loss: 3.3652 - acc: 0.4026 - val_loss: 3.2194 - val_acc: 0.4517

# %%
from keras.models import Model
from keras.layers import Embedding, Dense, Input, BatchNormalization, Dropout
from keras.regularizers import l2

embedding_dim = 50  # dimension of document embedding
n_docs = len(brown.categories()) + len(gutenberg.fileids())  # number of docs in corpus
vec_dim = 100  # dimension of word embedding vectors
hidden_size = 64  # dimension of hidden layer
vocab_size = len(vocab) # number of words in vocab
batch_size = 64 



# input layer for document id
doc_input = Input(shape=(1,), name="doc_input", dtype='int32')
# input layer for concatenated word vectors
words_input = Input(shape=(vec_dim*3,), name="word1_input", dtype='float32')

# document embedding layer
x_1 = keras.layers.Flatten()(Embedding(input_dim=n_docs, 
                                                          output_dim=embedding_dim, name='embeddings')(doc_input))
# concatenate document and word embeddings
X = BatchNormalization()(keras.layers.concatenate([x_1, words_input]))
# pass through hidden layer
X = Dropout(0.5)(BatchNormalization()(Dense(hidden_size, activation='relu', kernel_regularizer=l2(0.01))(X)))
# output softmax probailities
output = Dense(vocab_size, activation='softmax')(X)

model4 = Model(inputs = [doc_input, words_input], outputs=[output])

# %%
model4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model4.fit([doc_ids, word_input_mat], [labels_one_hot], epochs=5, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 174064 samples, validate on 43517 samples
# Epoch 1/5
# 174064/174064 [==============================] - 678s 4ms/step - loss: 4.3708 - acc: 0.3974 - val_loss: 3.4266 - val_acc: 0.4493
# Epoch 2/5
# 174064/174064 [==============================] - 653s 4ms/step - loss: 3.2474 - acc: 0.4297 - val_loss: 3.0697 - val_acc: 0.4581
# Epoch 3/5
# 174064/174064 [==============================] - 644s 4ms/step - loss: 2.9164 - acc: 0.4374 - val_loss: 2.9344 - val_acc: 0.4650
# Epoch 4/5
# 174064/174064 [==============================] - 674s 4ms/step - loss: 2.7350 - acc: 0.4415 - val_loss: 2.8412 - val_acc: 0.4641
# Epoch 5/5
# 174064/174064 [==============================] - 646s 4ms/step - loss: 2.6290 - acc: 0.4426 - val_loss: 2.8047 - val_acc: 0.4697

# %%
np.savez('10000_words_data', doc_ids=doc_ids, word_input_mat=word_input_mat, labels_one_hot=labels_one_hot)

# %%
model4.fit([doc_ids, word_input_mat], [labels_one_hot], epochs=5, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 174064 samples, validate on 43517 samples
# Epoch 1/5
# 174064/174064 [==============================] - 657s 4ms/step - loss: 2.5689 - acc: 0.4438 - val_loss: 2.7694 - val_acc: 0.4697
# Epoch 2/5
# 174064/174064 [==============================] - 924s 5ms/step - loss: 2.5280 - acc: 0.4458 - val_loss: 2.7831 - val_acc: 0.4659
# Epoch 3/5
# 174064/174064 [==============================] - 634s 4ms/step - loss: 2.4986 - acc: 0.4449 - val_loss: 2.7375 - val_acc: 0.4695
# Epoch 4/5
# 174064/174064 [==============================] - 644s 4ms/step - loss: 2.4751 - acc: 0.4467 - val_loss: 2.7236 - val_acc: 0.4717
# Epoch 5/5
# 174064/174064 [==============================] - 640s 4ms/step - loss: 2.4597 - acc: 0.4465 - val_loss: 2.7394 - val_acc: 0.4723

# %%
embed = model4.layers[1].get_weights()[0]

# %%
embed.shape
# Out:
# (33, 50)

# %%
scaler = StandardScaler()
standardized_embeddings = scaler.fit_transform(embed)

tsne_1 = TSNE(random_state=42, perplexity=1.5)
embeddings_2d_tsne = tsne_1.fit_transform(standardized_embeddings)

pca_1 = PCA(n_components=2)
embeddings_2d_pca = pca_1.fit_transform(standardized_embeddings)

# %%
plt.scatter(embeddings_2d_pca[:,0], embeddings_2d_pca[:,1])

for label, x, y in zip(brown.categories() + gutenberg.fileids(), embeddings_2d_pca[:, 0], embeddings_2d_pca[:, 1]):
    plt.annotate(
        label,
        xy=(x, y), xytext=(-2, y),
        textcoords='offset points', ha='right', va='bottom')
plt.show()

# %%
plt.scatter(embeddings_2d_tsne[:,0], embeddings_2d_tsne[:,1])

for label, x, y in zip(brown.categories() + gutenberg.fileids(), embeddings_2d_tsne[:, 0], embeddings_2d_tsne[:, 1]):
    plt.annotate(
        label,
        xy=(x, y), xytext=(-2,0),
        textcoords='offset points', ha='right', va='bottom')
plt.show()

# %%
from keras.models import Model
from keras.layers import Embedding, Dense, Input, BatchNormalization, Dropout
from keras.regularizers import l2

embedding_dim = 50  # dimension of document embedding
n_docs = len(brown.categories()) + len(gutenberg.fileids())  # number of docs in corpus
vec_dim = 100  # dimension of word embedding vectors
hidden_size = 75  # dimension of hidden layer
vocab_size = len(vocab) # number of words in vocab
batch_size = 64 



# input layer for document id
doc_input = Input(shape=(1,), name="doc_input", dtype='int32')
# input layer for concatenated word vectors
words_input = Input(shape=(vec_dim*3,), name="word1_input", dtype='float32')

# document embedding layer
x_1 = keras.layers.Flatten()(Embedding(input_dim=n_docs, 
                                                          output_dim=embedding_dim, name='embeddings')(doc_input))
# concatenate document and word embeddings
X = BatchNormalization()(keras.layers.concatenate([x_1, words_input]))
# pass through hidden layer
X = Dropout(0.3)(BatchNormalization()(Dense(hidden_size, activation='relu', kernel_regularizer=l2(0.01))(X)))
# output softmax probailities
output = Dense(vocab_size, activation='softmax')(X)

model5 = Model(inputs = [doc_input, words_input], outputs=[output])

# %%
model5.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model5.fit([doc_ids, word_input_mat], [labels_one_hot], epochs=5, batch_size=batch_size, validation_split=0.2)
# Out:
# Train on 174064 samples, validate on 43517 samples
# Epoch 1/5
#  52800/174064 [========>.....................] - ETA: 7:31 - loss: 5.1977 - acc: 0.3700
